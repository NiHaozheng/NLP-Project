# %%
import pickle

# %%
twitter = pickle.load(open('raw.pickle','rb'))

# %%
twitter.keys()
# Out:
# ['info', 'texts', 'val_ind', 'test_ind', 'train_ind']

# %%
twitter['info']
# Out:
# [{'label': array([ 1.,  0.,  0.,  0.,  0.,  0.,  0.])},
#  {'label': array([ 0.,  1.,  0.,  0.,  0.,  0.,  0.])},
#  {'label': array([ 0.,  0.,  1.,  0.,  0.,  0.,  0.])},
#  {'label': array([ 0.,  0.,  0.,  1.,  0.,  0.,  0.])},
#  {'label': array([ 0.,  0.,  0.,  0.,  1.,  0.,  0.])},
#  {'label': array([ 0.,  0.,  0.,  0.,  0.,  1.,  0.])},
#  {'label': array([ 0.,  0.,  0.,  0.,  0.,  0.,  1.])},
#  {'label': array([ 1.,  0.,  0.,  0.,  0.,  0.,  0.])},
#  {'label': array([ 0.,  1.,  0.,  0.,  0.,  0.,  0.])},
#  {'label': array([ 0.,  0.,  1.,  0.,  0.,  0.,  0.])},
#  {'label': array([ 0.,  0.,  0.,  1.,  0.,  0.,  0.])},
#  {'label': array([ 0.,  0.,  0.,  0.,  1.,  0.,  0.])},
#  {'label': array([ 0.,  0.,  0.,  0.,  0.,  1.,  0.])},
#  {'label': array([ 0.,  0.,  0.,  0.,  0.,  0.,  1.])},
#  {'label': array([ 1.,  0.,  0.,  0.,  0.,  0.,  0.])},
#  {'label': array([ 0.,  1.,  0.,  0.,  0.,  0.,  0.])},
#  {'label': array([ 0.,  0.,  1.,  0.,  0.,  0.,  0.])},
# ...
